# %%
import cv2

# %%
cap = cv2.VideoCapture('Assets/meme.mp4')

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps = cap.get(cv2.CAP_PROP_FPS)

print(f'FPS: {fps}')
print(f'Width: {width}')
print(f'Height: {height}')
# Out:
# FPS: 30.0
# Width: 854.0
# Height: 480.0

# %%
while True:

    ret, frame = cap.read()

    if not ret:
        break
    cv2.line(frame, (200,200), (500,300), (0, 255, 0), 2)

    cv2.rectangle(frame, (200,200), (500,300), (255, 0, 0), 2)

    cv2.circle(frame, (350,250), 50, (0,0,255), 2)

    cv2.putText(frame, 'KANA', (300, 350), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
    cv2.imshow('Meme',frame)

    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Live Webcam

cap = cv2.VideoCapture(0)

width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
fps = cap.get(cv2.CAP_PROP_FPS)

print(f'FPS: {fps}')
print(f'Width: {width}')
print(f'Height: {height}')
# Out:
# FPS: 30.0
# Width: 640.0
# Height: 480.0

# %%
while True:

    ret, frame = cap.read()

    if not ret:
        break

    cv2.rectangle(frame, (200,100), (400,300), (255, 0, 0), 2)

    cv2.imshow('Live Webcam', frame)

    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# Save video

cap = cv2.VideoCapture('Assets/meme.mp4')

fps = cap.get(cv2.CAP_PROP_FPS)
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
writer = cv2.VideoWriter('Assets/meme_saved.mp4', fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()

    if not ret:
        break

    cv2.rectangle(frame, (200,100), (400,400), (255, 0, 0), 2)
    cv2.imshow('Meme_', frame)

    writer.write(frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break
cap.release()
writer.release()
cv2.destroyAllWindows()
